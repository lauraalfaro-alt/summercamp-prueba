# %% [markdown]
# <a href="https://colab.research.google.com/github/lauraalfaro-alt/summercamp-prueba/blob/main/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("me gusta el verde")
# Out:
# me gusta el verde

# %%
Jugador = "Kirby"
print(Jugador,"perdio la partida")
Jugador2 = "Linkin"
print(Jugador2,"gano la partida ")
# Out:
# Kirby perdio la partida
# Linkin gano la partida
